# %%
import numpy as np
import pandas as pd
import matplotlib
import plotly
import os
import glob
import plotly.express as px

# %%
#path to the experiments log folder
log_data_dir = "/nfs/lslab2/fireline/simharness/experiments/"

#model type in experiment folder
model = 'DQN'

#output folder
outputs = "exp_reports/"

#enter the experiment number here
exp = '2023-09-27_19-44-13'

# %%
#concatenate the experiment directory path
exp_dir = log_data_dir + exp + "/" + model + "/"

#get the name of the directory that holds the gifs and csv logs
log_dir_name = [s for s in os.listdir(exp_dir) if model in s][0]

#get the full path of the log directory 
log_dir = exp_dir + log_dir_name + "/"

print("Directory with callback logs and gifs:")
print(log_dir)
print("Directory Contains:")
print(os.listdir(log_dir))
# Out:
# Directory with callback logs and gifs:
# /nfs/lslab2/fireline/simharness/experiments/2023-09-27_19-44-13/DQN/DQN_simharness2.environments.reactive.ReactiveHarness_48aba_00000_0_2023-09-27_19-44-37/
# Directory Contains:
# ['params.json', 'params.pkl', 'result.json', 'events.out.tfevents.1695843984.sh2DG', 'progress.csv', 'gifs', 'sim_data', 'benchsim_data', 'checkpoint_000020', 'checkpoint_000040', 'checkpoint_000060']

# %% [markdown]
# ### Visualize the Benchsim Results

# %%
#get the most recent log in the benchsim folder for the bench_sim stats
##this assumes that all the benchsim stats are the same
benchsim_eval_log = max(([os.path.join((log_dir + "benchsim_data/"), basename) for basename in os.listdir((log_dir + "benchsim_data/"))]), key=os.path.getctime)
print(benchsim_eval_log)

#turn the benchsim data into a dataframe
benchsim_data = pd.read_csv(benchsim_eval_log, header=0, index_col=0)
print(benchsim_data.head())
# Out:
# /nfs/lslab2/fireline/simharness/experiments/2023-09-27_19-44-13/DQN/DQN_simharness2.environments.reactive.ReactiveHarness_48aba_00000_0_2023-09-27_19-44-37/benchsim_data/eval_iter_7.csv
#           timestep  burned  burning  unburned
# sim_step
# 0                0       0        3     16381
# 1                4       0        6     16378
# 2                8       0       10     16374
# 3               12       0       15     16369
# 4               16       1       20     16363

# %%
benchsim_plot = px.line(benchsim_data, x="timestep", y=['unburned', 'burning', 'burned'], title='Benchsim Analytics')
benchsim_plot.show()
# Out:
# <div>                            <div id="a2d8350b-b71a-4aea-9332-dd6ae1bd9dbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2d8350b-b71a-4aea-9332-dd6ae1bd9dbf")) {                    Plotly.newPlot(                        "a2d8350b-b71a-4aea-9332-dd6ae1bd9dbf",                        [{"hovertemplate":"variable=unburned<br>timestep=%{x}<br>value=%{y}<extra></extra>","legendgroup":"unburned","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"unburned","orientation":"v","showlegend":true,"x":[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116,120,124,128,132,136,140,144,148,152,156,160,164,168,172,176,180,184,188,192,196,200,204,208,212,216,220,224,228,232,236,240,244,248,252,256,260,264,268,272,276,280,284,288,292,296,300,304,308,312,316,320,324,328,332,336,340,344,348,352,356,360,364,368,372,376,380,384,388,392
#or choose an agent_eval_log
##print possible files
#print(((log_dir + "sim_data/")))
agent_iter_number = 7
agent_eval_log = log_dir + "sim_data/eval_iter_" + str(agent_iter_number) + ".csv"

#turn the benchsim data into a dataframe
agent_data = pd.read_csv(agent_eval_log, header=0, index_col=0)

# %%
#merge in the benchmark sim data to create the simharness_analytics dataframe
benchmark_analytics = benchsim_data[['timestep', 'burned', 'burning', 'unburned']].copy()
benchmark_analytics.rename(columns={"burned": "unmitigated_burned", "burning": "unmitigated_burning", "unburned": "unmitigated_unburned"}, inplace=True)
eval_analytics = agent_data.merge(benchmark_analytics, how='inner', on='timestep')
print(eval_analytics.head())
# Out:
#    timestep  burned  burning  unburned  mitigated  agent_interactions  \
# 0         0       0        3     16381          0                   0
# 1         4       0        6     16376          2                   2
# 2         8       0       10     16370          4                   3
# 3        12       0       15     16364          5                   2
# 4        16       1       20     16357          6                   2
#
#    agent_movements  unmitigated_burned  unmitigated_burning  \
# 0                1                   0                    3
# 1                4                   0                    6
# 2                3                   0                   10
# 3                3                   0                   15
# 4                4                   1                   20
#
#    unmitigated_unburned
# 0                 16381
# 1                 16378
# 2                 16374
# 3                 16369
# 4                 16363

# %%
sh_burned_plot = px.line(eval_analytics, x="timestep", y=['mitigated','burned','unmitigated_burned'], title='SimHarness Performance Analysis')
sh_burned_plot.show()
# Out:
# <div>                            <div id="235bc6cd-a9c2-4843-8114-7ca5b82a6f17" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("235bc6cd-a9c2-4843-8114-7ca5b82a6f17")) {                    Plotly.newPlot(                        "235bc6cd-a9c2-4843-8114-7ca5b82a6f17",                        [{"hovertemplate":"variable=mitigated<br>timestep=%{x}<br>value=%{y}<extra></extra>","legendgroup":"mitigated","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"mitigated","orientation":"v","showlegend":true,"x":[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116,120,124,128,132,136,140,144,148,152,156,160,164,168,172,176,180,184,188,192,196,200,204,208,212,216,220,224,228,232,236,240,244,248,252,256,260,264,268,272,276,280,284,288,292,296,300,304,308,312,316,320,324,328,332,336,340,344,348,352,356,360,364,368,372,376,380,384,388,392,396,400,404,408,412,416,420,424,428,432,436,440,444,448,452,456,460,464,468,472,476,480,484,488,492,496,500,504,508,512,516,520,524,528,532,536,540,544,548,552,556,560,564,568,572,576,580,584,588,592,596,600,604,608,612,616,620,624,628,632,636,640,644,648,652,656,660,664,668,672,676,680,684,688,692,696,700,704,708,712,716,720,724,728,732,736,740,744,748,752,756,760,764,768,772,776,780,784,788,792,796,800,804,808,812,816,820,824,828,832,836,840,844,848,852,856,860,864,868,872,876,880,884,888,892,896,900,904,908,912,916,920,924,928,932,936,940,944,948,952,956,960,964,968,972,976,980,984,988,992,996,1000,1004,1008,1012,1016,1020,1024,1028,1032],"xaxis":"x","y":[0,2,4,5,6,8,9,11,12,15,17,18,20,23,25,27,27,29,32,34,37,37,39,41,42,45,48,50,52,55,59,63,65,69,72,72,74,77,80,84,85,88,90,93,95,97,101,105,109,111,115,118,119,122,124,125,126,126,126,126,128,129,131,133,135,137,139,141,144,145,145,145,145,145,146,147,150,152,156,158,158,158,158,158,158,158,158,158,158,158,158,158,158,158,158,159,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160,160
"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=agent_interactions<br>timestep=%{x}<br>value=%{y}<extra></extra>","legendgroup":"agent_interactions","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"agent_interactions","orientation":"v","showlegend":true,"x":[0,4,8,12,16,20,24,28,32,36,40,44,48,52,56,60,64,68,72,76,80,84,88,92,96,100,104,108,112,116,120,124,128,132,136,140,144,148,152,156,160,164,168,172,176,180,184,188,192,196,200,204,208,212,216,220,224,228,232,236,240,244,248,252,256,260,264,268,272,276,280,284,288,292,296,300,304,308,312,316,320,324,328,332,336,340,344,348,352,356,360,364,368,372,376,380,384,388,392,396,400,404,408,412,416,420,424,428,432,436,440,444,448,452,456,460,464,468,472,476,480,484,488,492,496,500,504,508,512,516,520,524,528,532,536,540,544,548,552,556,560,564,568,572,576,580,584,588,592,596,600,604,608,612,616,620,624,628,632,636,640,644,648,652,656,660,664,668,672,676,680,684,688,692,696,700,704,708,712,716,720,724,728,732,736,740,744,748,752,756,760,764,768,772,776,780,784,788,792,796,800,804,808,812,816,820,824,828,832,836,840,844,848,852,856,860,864,868,872,876,880,884,888,892,896,900,904,9 ...

# %% [markdown]
# ## Cumulative Agent Analysis

# %%
agent_log_dir = log_dir + "sim_data/"
simharness_analytics = pd.DataFrame(columns=['Eval_Num', 'Num_timesteps', 'Num_burned', 'Num_unburned', 'Num_mitigated'])

for basepath in os.listdir(agent_log_dir):
    #get the eval_num from the csv file name
    eval_num = basepath.replace('eval_iter_', '')
    eval_num = eval_num.replace('.csv', '')
    eval_num = int(eval_num)
    
    #take the last row of the eval_iter_#.csv and translate those values into our dataframe
    single_agent_data = pd.read_csv((agent_log_dir + basepath), header=0, index_col=0)
    last_row = single_agent_data.iloc[-1:]
    #print(type(last_row.timestep.iloc[0]))
    final_run_data= [eval_num, int((last_row.timestep.iloc[0])), int((last_row.burned.iloc[0])), int((last_row.unburned.iloc[0])),int((last_row.mitigated.iloc[0]))]
    
    #place that last row data into the dataframe
    simharness_analytics.loc[len(simharness_analytics)] = final_run_data

print(simharness_analytics.head())
# Out:
#    Eval_Num  Num_timesteps  Num_burned  Num_unburned  Num_mitigated
# 0         1           1032       16306             0             78
# 1         2           1032       16255             0            129
# 2         3           1032       16230             0            154
# 3         4           1032       16322             0             62
# 4         5           1032       16214             0            170

# %%
sh_cumulative_plot = px.line(simharness_analytics, x="Eval_Num", y=['Num_burned','Num_unburned','Num_mitigated'], title='SimHarness Performance Analysis')
sh_cumulative_plot.show()
# Out:
# <div>                            <div id="b4832512-88a9-4358-a171-8f93c9d5a06a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4832512-88a9-4358-a171-8f93c9d5a06a")) {                    Plotly.newPlot(                        "b4832512-88a9-4358-a171-8f93c9d5a06a",                        [{"hovertemplate":"variable=Num_burned<br>Eval_Num=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Num_burned","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Num_burned","orientation":"v","showlegend":true,"x":[1,2,3,4,5,6,7],"xaxis":"x","y":[16306,16255,16230,16322,16214,16224,16221],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Num_unburned<br>Eval_Num=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Num_unburned","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Num_unburned","orientation":"v","showlegend":true,"x":[1,2,3,4,5,6,7],"xaxis":"x","y":[0,0,0,0,0,0,0],"yaxis":"y","type":"scatter"},{"hovertemplate":"variable=Num_mitigated<br>Eval_Num=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Num_mitigated","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Num_mitigated","orientation":"v","showlegend":true,"x":[1,2,3,4,5,6,7],"xaxis":"x","y":[78,129,154,62,170,160,163],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.888888888 ...
